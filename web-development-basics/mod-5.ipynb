# %% [markdown]
# # Module 5: Core Concepts
#
# **Duration:** 5 min
#
# ## Introduction
#
# Detailed explanation of the concept

# %%
# Example code

# %% [markdown]
# > **Try it in Google Colab:** [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shastrula/ailearningclub-courses/blob/main/web-development-basics/mod-5.ipynb)
#
#
# > **💡 Tip:** Best practice tip
#
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ Test question?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4375014464" value="0">
#       <span>A</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4375014464" value="1">
#       <span>B</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4375014464" value="2">
#       <span>C</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4375014464" value="3">
#       <span>D</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
