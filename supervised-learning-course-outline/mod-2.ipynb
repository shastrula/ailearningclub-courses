# %% [markdown]
# # Data Preparation and Preprocessing
#
# **Duration:** 5 min
#
# Data preparation and preprocessing are crucial steps in the supervised learning pipeline. They ensure that the data is clean, consistent, and suitable for training machine learning models.
#
# ## Handling Missing Data
#
# Missing data can skew the results of a machine learning model. Common techniques to handle missing data include removing rows with missing values or imputing missing values with statistical measures like mean, median, or mode.

# %%
import pandas as pd
from sklearn.impute import SimpleImputer

# Load dataset
data = pd.read_csv('data.csv')

# Impute missing values with mean
imputer = SimpleImputer(strategy='mean')
data_imputed = pd.DataFrame(imputer.fit_transform(data), columns=data.columns)
print(data_imputed)

# %% [markdown]
# > **Try it in Google Colab:** [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shastrula/ailearningclub-courses/blob/main/supervised-learning-course-outline/mod-2.ipynb)
#
#
# > **💡 Tip:** Always check for missing values before training your model and decide on an appropriate strategy to handle them.
#
# <div class="quiz" data-correct="2">
#   <p class="font-semibold mb-3">❓ Which method is best for imputing missing values in a dataset with a mix of numerical and categorical data?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4374077888" value="0">
#       <span>Mean</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4374077888" value="1">
#       <span>Median</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4374077888" value="2">
#       <span>Mode</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4374077888" value="3">
#       <span>K-Nearest Neighbors</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
#
# ## Encoding Categorical Variables
#
# Machine learning algorithms require numerical input. Categorical variables need to be converted into a numerical format using techniques like one-hot encoding or label encoding.

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# Load dataset
data = pd.read_csv('data.csv')

# One-hot encode categorical variables
encoder = OneHotEncoder(sparse=False)
data_encoded = pd.DataFrame(encoder.fit_transform(data[['category_column']]))
data_encoded.columns = encoder.get_feature_names_out(['category_column'])
data = pd.concat([data, data_encoded], axis=1)
print(data)

# %% [markdown]
# > **💡 Tip:** Use one-hot encoding for nominal categorical variables and label encoding for ordinal categorical variables.
#
# <div class="quiz" data-correct="2">
#   <p class="font-semibold mb-3">❓ What is the primary disadvantage of using one-hot encoding?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4374072704" value="0">
#       <span>Increases dataset size</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4374072704" value="1">
#       <span>Does not handle new categories well</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4374072704" value="2">
#       <span>Both A and B</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4374072704" value="3">
#       <span>None of the above</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
#
# ## Feature Scaling
#
# Feature scaling ensures that all features contribute equally to the result by bringing all features to the same scale, typically between 0 and 1 or -1 and 1.

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# Sample data
data = np.array([[1, 2], [3, 4], [5, 6]])

# Feature scaling
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)
print(data_scaled)

# %% [markdown]
# > **💡 Tip:** Always perform feature scaling after splitting the data into training and testing sets to avoid data leakage.
#
# <div class="quiz" data-correct="2">
#   <p class="font-semibold mb-3">❓ Which of the following is a common method for feature scaling?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4372660160" value="0">
#       <span>Normalization</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4372660160" value="1">
#       <span>Standardization</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4372660160" value="2">
#       <span>Both A and B</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4372660160" value="3">
#       <span>None of the above</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
#
# ## Data Transformation
#
# Data transformation involves converting data into a format suitable for modeling. This can include normalization, standardization, and the creation of new features.

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# Sample data
data = np.array([[1, 2], [3, 4], [5, 6]])

# Standardization
scaler = StandardScaler()
data_standardized = scaler.fit_transform(data)
print(data_standardized)

# %% [markdown]
# > **💡 Tip:** Transformations should be applied consistently to both training and testing datasets.
#
# <div class="quiz" data-correct="2">
#   <p class="font-semibold mb-3">❓ Why is it important to apply the same transformation to both training and testing data?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4372644480" value="0">
#       <span>To maintain consistency</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4372644480" value="1">
#       <span>To avoid data leakage</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4372644480" value="2">
#       <span>Both A and B</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4372644480" value="3">
#       <span>None of the above</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
