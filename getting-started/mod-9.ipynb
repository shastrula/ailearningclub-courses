# %% [markdown]
# # Next Steps in Your AI Journey
#
# **Duration:** 5 min
#
# ## What You've Learned
#
# Congratulations! You now know:
# - How to use Git for version control
# - How to push code to GitHub/GitLab
# - Python fundamentals
# - How to build and train a machine learning model
#
# ## Recommended Next Courses
#
# Continue your learning journey with these courses:
#
# 1. <a href="https://ailearningclub.com/course.html?id=python-fundamentals" target="_blank">Python Fundamentals</a> - Deepen your Python skills
# 2. <a href="https://ailearningclub.com/course.html?id=ai-fundamentals" target="_blank">AI Fundamentals</a> - Learn core ML concepts
# 3. <a href="https://ailearningclub.com/course.html?id=deep-learning" target="_blank">Deep Learning</a> - Build neural networks
# 4. <a href="https://ailearningclub.com/course.html?id=rag-systems" target="_blank">RAG Systems</a> - Build AI applications with retrieval
#
# ## Practice Projects
#
# - Build a classifier for a different dataset
# - Create a prediction API with Flask
# - Contribute to open-source ML projects on GitHub
# - Build a chatbot using NLP techniques
#
# > **💡 Tip:** The best way to learn is by doing. Start small, commit often, and gradually build more complex projects.
#
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What is the most important habit for AI developers?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4386898176" value="0">
#       <span>Writing perfect code on the first try</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4386898176" value="1">
#       <span>Using Git to track changes and collaborate</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4386898176" value="2">
#       <span>Memorizing all algorithms</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4386898176" value="3">
#       <span>Working alone on projects</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
