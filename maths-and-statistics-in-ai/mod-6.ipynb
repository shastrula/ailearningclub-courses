# %% [markdown]
# # Data Visualization Techniques
#
# **Duration:** 5 min
#
# This module delves into the essential role of data visualization in artificial intelligence, exploring how visual representations can simplify complex data, uncover patterns, and facilitate better decision-making. Understanding these techniques is crucial for effectively communicating insights derived from data analysis.
#
# ## Understanding Scatter Plots
#
# Scatter plots are a fundamental visualization technique used to display the relationship between two variables. They are particularly useful in identifying correlations, trends, and outliers within the data. By plotting points on a two-dimensional plane, scatter plots provide a clear visual representation of the data distribution.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
x = np.random.rand(50)
y = np.random.rand(50)

# Create a scatter plot
plt.scatter(x, y)

# Add title and labels
plt.title('Scatter Plot Example')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Display the plot
plt.show()

# %% [markdown]
# > **Try it in Google Colab:** [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shastrula/ailearningclub-courses/blob/main/maths-and-statistics-in-ai/mod-6.ipynb)

# %% [markdown]
# ```
# A scatter plot with 50 points randomly distributed on a 2D plane with axes labeled 'X-axis' and 'Y-axis', and a title 'Scatter Plot Example'.
# ```

# %% [markdown]
# ## Creating Histograms
#
# Histograms are used to visualize the distribution of a single variable. They group data into bins and count the number of observations that fall into each bin. This helps in understanding the underlying distribution of the data, such as identifying skewness, kurtosis, and the presence of outliers.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
data = np.random.randn(1000)

# Create a histogram
plt.hist(data, bins=30, alpha=0.5, color='blue')

# Add title and labels
plt.title('Histogram Example')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %% [markdown]
# > **💡 Tip:** When creating histograms, choose an appropriate number of bins to ensure that the distribution is clearly visible without overfitting the data.
#
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What is the primary purpose of a scatter plot?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4386865088" value="0">
#       <span>To display the distribution of a single variable</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4386865088" value="1">
#       <span>To show the relationship between two variables</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4386865088" value="2">
#       <span>To compare different categories</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4386865088" value="3">
#       <span>To visualize time-series data</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
#
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ Which parameter in the histogram function controls the number of bins?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4386854912" value="0">
#       <span>color</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4386854912" value="1">
#       <span>bins</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4386854912" value="2">
#       <span>alpha</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4386854912" value="3">
#       <span>edgecolor</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
