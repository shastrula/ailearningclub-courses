# %% [markdown]
# # Project 1 — Titanic: EDA & Feature Engineering
#
# **Duration:** 5 min
#
# ## Step 1: Load & Explore

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('train.csv')
print(df.shape)          # (891, 12)
print(df.isnull().sum())  # check missing values
df.head()

# %% [markdown]
# > **Try it in Google Colab:** [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shastrula/ailearningclub-courses/blob/main/ai-projects-beginner/bp-project1-eda.ipynb)
#
#
# ## Step 2: Handle Missing Values

# %%
# Fill Age with median, Embarked with mode, drop Cabin
df['Age'].fillna(df['Age'].median(), inplace=True)
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
df.drop(columns=['Cabin'], inplace=True)

# %% [markdown]
# ## Step 3: Feature Engineering

# %%
# Family size and title extraction
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
df['Title'] = df['Name'].str.extract(r' ([A-Za-z]+)\.', expand=False)
df['Title'] = df['Title'].replace(['Lady','Countess','Capt','Col','Don','Dr',
                                    'Major','Rev','Sir','Jonkheer','Dona'], 'Rare')
df['Title'] = df['Title'].replace({'Mlle':'Miss','Ms':'Miss','Mme':'Mrs'})

# %% [markdown]
# > **💡 Tip:** Survival rate by Title is one of the strongest predictors. Mr has ~16% survival, Mrs ~79%, Miss ~70%.
#
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ Which feature has the strongest correlation with survival in the Titanic dataset?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4374089152" value="0">
#       <span>Age</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4374089152" value="1">
#       <span>Sex</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4374089152" value="2">
#       <span>Fare</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4374089152" value="3">
#       <span>Pclass</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
